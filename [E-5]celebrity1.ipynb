# %%
import os

dir_path = os.getenv('HOME')+'/aiffel/face_embedding/celebrity'
file_list = os.listdir(dir_path)

print ("file_list: {}".format(file_list))

import matplotlib.pyplot as plt
import matplotlib.image as img

#Set figsize here
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(24,10))

# flatten axes for easy iterating
for i, ax in enumerate(axes.flatten()):
  image = img.imread(dir_path+'/'+file_list[i])
  ax.imshow(image)
plt.show()

fig.tight_layout()
# Out:
# file_list: ['레드벨벳웬디.jpg', '크리스탈.jpg', '지디.jpg', '정국.jpg', '장성호.jpeg', '최민식.jpg', '박건우.png', '조이.jpg', '김현수.jpeg', '고창석.jpeg', '김상호.png', '첸.jpg', '백현.jpg', '트와이스정연.jpg', '박완규.png', '브래들리 쿠퍼.jpg', '박해일.jpeg', '서강준.jpg', '다니엘 크레이그.jpeg', '문별.jpg', '김구라.jpg', '김유정.jpg', '크리스 에반스.jpg', '공유.jpg', 'me1.jpeg', '도지한.jpg', '류승범.jpg', '이재용.jpg', '제이콥 배털론.jpg', '박찬욱.jpeg', '조인성.jpg', '배성재.jpg', '태양.jpeg', '장동건.jpeg', '이영하.jpg', '류현진.jpg', '곽도원.jpg', '클린트 이스트우드.jpg', '박용택.jpg', '지수.jpg', '박보검.jpg', '이종석.jpeg', '정준하.jpg', '러블리즈예인.jpg', '로제.jpg', '박신양.png', '최무성.jpg', '지호.jpg', '아린.jpg', '이정재.jpeg', '사쿠라.jpg', '서현진.jpg', '제이홉.jpg', '차명석.jpg', '김희철.jpg', '김대중.jpg', '정우성.jpeg', '김광현.jpg', '김학범.jpg', '류승룡.jpeg', '트
# ...

# %%
import face_recognition
import os
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.getenv('HOME')+'/aiffel/face_embedding/celebrity/me1.jpeg'
image = face_recognition.load_image_file(image_path)
face_locations = face_recognition.face_locations(image)

print(face_locations)  # 이미지에서 얼굴 영역의 좌표를 출력합니다.

a, b, c, d = face_locations[0]
cropped_face = image[a:c,d:b,:]

plt.imshow(cropped_face)   # 이미지에서 얼굴영역만 잘라낸 cropped_face를 그려 봅니다.
# Out:
# [(313, 598, 634, 277)]

# %%
import face_recognition
import os

def get_cropped_face(image_file):
    image = face_recognition.load_image_file(image_file)
    face_locations = face_recognition.face_locations(image)
    a, b, c, d = face_locations[0]
    cropped_face = image[a:c,d:b,:]
    
    return cropped_face

# %%
image_path = os.getenv('HOME')+'/aiffel/face_embedding/celebrity/me1.jpeg'

cropped_face = get_cropped_face(image_path)
plt.imshow(cropped_face)

# %% [markdown]
# **def get_face_embedding**

# %%
import os

dir_path = os.getenv('HOME') + "/aiffel/face_embedding/celebrity/"
file_list = os.listdir(dir_path)

print ("file_list: {}".format(file_list))
# Out:
# file_list: ['레드벨벳웬디.jpg', '크리스탈.jpg', '지디.jpg', '정국.jpg', '장성호.jpeg', '최민식.jpg', '박건우.png', '조이.jpg', '김현수.jpeg', '고창석.jpeg', '김상호.png', '첸.jpg', '백현.jpg', '트와이스정연.jpg', '박완규.png', '브래들리 쿠퍼.jpg', '박해일.jpeg', '서강준.jpg', '다니엘 크레이그.jpeg', '문별.jpg', '김구라.jpg', '김유정.jpg', '크리스 에반스.jpg', '공유.jpg', 'me1.jpeg', '도지한.jpg', '류승범.jpg', '이재용.jpg', '제이콥 배털론.jpg', '박찬욱.jpeg', '조인성.jpg', '배성재.jpg', '태양.jpeg', '장동건.jpeg', '이영하.jpg', '류현진.jpg', '곽도원.jpg', '클린트 이스트우드.jpg', '박용택.jpg', '지수.jpg', '박보검.jpg', '이종석.jpeg', '정준하.jpg', '러블리즈예인.jpg', '로제.jpg', '박신양.png', '최무성.jpg', '지호.jpg', '아린.jpg', '이정재.jpeg', '사쿠라.jpg', '서현진.jpg', '제이홉.jpg', '차명석.jpg', '김희철.jpg', '김대중.jpg', '정우성.jpeg', '김광현.jpg', '김학범.jpg', '류승룡.jpeg', '트
# ...

# %%
image_file = os.path.join(dir_path, 'me1.jpeg')
face = get_cropped_face(image_file)   # 얼굴 영역을 구하는 함수(이전 스텝에서 구현)

# 얼굴 영역을 가지고 얼굴 임베딩 벡터를 구하는 함수
def get_face_embedding(face):
    return face_recognition.face_encodings(face)

embedding = get_face_embedding(face)
embedding
# Out:
# [array([-8.41488391e-02,  7.76109770e-02,  2.28507854e-02, -4.48510498e-02,
#         -5.46435975e-02, -7.22328126e-02, -7.40498826e-02, -9.91550311e-02,
#          1.35558918e-01, -3.61258164e-03,  2.86950022e-01, -5.82935363e-02,
#         -1.92223638e-01, -1.55029669e-01, -3.27364355e-02,  2.05215737e-01,
#         -1.97253555e-01, -1.21922672e-01, -4.47741821e-02, -6.09827880e-03,
#          1.32044300e-01,  2.49615521e-04,  3.59810218e-02,  7.45232627e-02,
#         -1.31711215e-01, -3.09079528e-01, -8.24560598e-02, -4.19048890e-02,
#          4.35439609e-02, -7.19825402e-02, -7.08016977e-02,  6.26092106e-02,
#         -2.39807844e-01, -8.60991180e-02,  7.95015544e-02,  1.02783255e-01,
#         -1.27948020e-02, -1.27841040e-01,  1.89196423e-01, -4.88485470e-02,
#         -2.11818486e-01,  8.23740810e-02,  7.70389885e-02,  2.39485323e-01,
#          1.79199681e-01, -1.64736249e-02,  3.63925993e-02, -1.64998278e-01,
# ...

# %%
def get_face_embedding_dict(dir_path):
    file_list = os.listdir(dir_path)
    embedding_dict = {}
  
    for file in file_list:
        img_path = os.path.join(dir_path, file)
        face = get_cropped_face(img_path)
        embedding = get_face_embedding(face)
        if len(embedding) > 0:  
        # 얼굴영역 face가 제대로 detect되지 않으면  len(embedding)==0인 경우가 발생하므로 
        # os.path.splitext(file)[0]에는 이미지파일명에서 확장자를 제거한 이름이 담깁니다.  
            embedding_dict[os.path.splitext(file)[0]] = embedding[0]
    return embedding_dict

# %%
embedding_dict = get_face_embedding_dict(dir_path)
embedding_dict['me3']
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-35-845dcf59b0c1> in <module>
# ----> 1 embedding_dict = get_face_embedding_dict(dir_path)
#       2 embedding_dict['me3']
#
# <ipython-input-29-e98f2788941c> in get_face_embedding_dict(dir_path)
#       5     for file in file_list:
#       6         img_path = os.path.join(dir_path, file)
# ----> 7         face = get_cropped_face(img_path)
#       8         embedding = get_face_embedding(face)
#       9         if len(embedding) > 0:
#
# <ipython-input-25-adedf16ca370> in get_cropped_face(image_file)
#       3
#       4 def get_cropped_face(image_file):
# ----> 5     image = face_recognition.load_image_file(image_file)
#       6     face_locations = face_recognition.face_locations(image)
#       7     a, b, c, d = face_locations[0]
#
# ...

# %% [markdown]
# **def get_distance()**

# %%
def get_nearest_face(name, top=5): 
    pass
get_nearest_face('trump')

# %%
# name1과 name2의 거리를 비교하는 함수를 생성하되, name1은 미리 지정하고, name2는 호출시에 인자로 받도록 합니다.
def get_sort_key_func(name1):
    def get_distance_from_name1(name2):
        return get_distance(name1, name2)
    return get_distance_from_name1

sort_key_func = get_sort_key_func('trump')   
# 이렇게 생성된 함수 sort_key_func는 sort_key_func('obama') 라고 호출할 때 trump와 obama 사이의 임베딩 벡터 거리를 계산합니다.

# %%
sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a8c8ab982dee> in <module>
# ----> 1 sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))
#
# NameError: name 'embedding_dict' is not defined

# %% [markdown]
# **죄송합니다 노드를 다 완료하지 못했습니다.. 이미지 경로가 맞는데 파일이 불러오지 않아서 퍼실님들께 물어봐서 한글이 깨지는 현상에 대해서는 알았는데 이 부분역시 막혀서 끙끙되다가 결국 완료하지 못했습니다 정말 죄송합니다 ㅠㅠ**

# %%
def get_nearest_face(name, top=5):
    sort_key_func = get_sort_key_func(name)
    sorted_faces = sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))
    
    for i in range(top+1):
        if i == 0 :   # 첫번째로 나오는 이름은 자기 자신일 것이므로 제외합시다. 
            continue
        if sorted_faces[i]:
            print('순위 {} : 이름({}), 거리({})'.format(i, sorted_faces[i][0], sort_key_func(sorted_faces[i][0])))

# %%
# obama와 가장 닮은 사람은 누굴까요?
get_nearest_face('obama')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-75f00eff6573> in <module>
#       1 # obama와 가장 닮은 사람은 누굴까요?
# ----> 2 get_nearest_face('obama')
#
# <ipython-input-36-9de01b791127> in get_nearest_face(name, top)
#       1 def get_nearest_face(name, top=5):
#       2     sort_key_func = get_sort_key_func(name)
# ----> 3     sorted_faces = sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))
#       4
#       5     for i in range(top+1):
#
# NameError: name 'embedding_dict' is not defined
